# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Load Dataset

# %%
batsman = pd.read_csv('/content/sharma-kohli.csv')
batsman.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %% [markdown]
# ## **Pratical - 1**
# - Create a simple bar chart using student marks or sales data and explain what it shows.

# %%
batsman = pd.read_csv('/content/sharma-kohli.csv')

plt.bar(batsman['index'], batsman['V Kohli'])

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("V Kohli Runs per Year")

plt.show()

# %% [markdown]
# ## **Pratical - 2**
# - Draw a line chart to represent time-based data (monthly attendance or sales).

# %%
batsman = pd.read_csv('/content/sharma-kohli.csv')

# labels & tittle
plt.plot(batsman['index'],batsman['V Kohli'],color='blue',marker='o',markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color='red',marker='o',markersize=10)

plt.title('Rohit Vs Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Run Score')
# Out:
# Text(0, 0.5, 'Run Score')

# %% [markdown]
# ## **Pratical - 3**
# - Perform data representation vs data presentation using at least two chart types

# %% [markdown]
# ### Chart–1: Data Representation (Bar Chart)

# %%
import matplotlib.pyplot as plt

# Bar chart for RG Sharma
plt.bar(batsman['index'], batsman['RG Sharma'])

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("RG Sharma Runs")

plt.show()

# %% [markdown]
# ### Chart–2: Data Presentation (Pie Chart)

# %%
plt.pie(batsman['RG Sharma'], labels=batsman['index'], autopct='%1.1f%%')

plt.title("RG Sharma Runs Distribution")

plt.show()

# %% [markdown]
# ## **Pratical - 4**
# - Identify the purpose of data visualization for a dataset and use a donut chart.

# %%
plt.pie(batsman['V Kohli'],labels=batsman['index'],autopct='%1.1f%%')

plt.title("V Kohli Runs Distribution")

# for Donut Chart
plt.gca().add_artist(plt.Circle((0,0), 0.4, color='white'))

plt.show()

# %% [markdown]
# ## **Pratical - 5**
# - Explain the seven stages of data visualization with a simple example.

# %% [markdown]
# ### 🔹 Step 1: Data Collection
# - Dataset: House Rent Price Prediction

# %%
import pandas as pd

df = pd.read_csv('/content/house_rent_dataset_.csv')
df.head(5)
# Out:
#    bedrooms  bathrooms  area_sqft  balconies  floor  location_rating  \
# 0         4        2.0      820.0          1     17                1
# 1         5        2.0      406.0          0     13                3
# 2         3        3.0     1948.0          1     13                4
# 3         5        1.0     2733.0          2      7                5
# 4         5        3.0     1070.0          1      9                5
#
#    age_years  furnishing  parking_spaces  distance_to_city_center_km  \
# 0         27           0               0                   12.954767
# 1          9           0               1                   21.128599
# 2         20           1               2                   20.038324
# 3          7           0               0                   10.911332
# 4          9           1               1                   24.428912
#
#    rent_price
# 0   45.622632
# 1   51.627563
# 2   90.343577
# 3  108.107763
# 4   75.923274

# %% [markdown]
# ### 🔹 Step 2: Data Cleaning
# - (Missing values + duplicate values)

# %%
# check missing values
df.isnull().sum()
# Out:
# bedrooms                        0
# bathrooms                     117
# area_sqft                     149
# balconies                       0
# floor                           0
# location_rating                 0
# age_years                       0
# furnishing                      0
# parking_spaces                  0
# distance_to_city_center_km      0
# rent_price                    100
# dtype: int64

# %% [markdown]
# - Remove duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(200)

# %% [markdown]
# - Fill missing values

# %%
df.fillna(df.mean(), inplace=True)
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# bedrooms                      0
# bathrooms                     0
# area_sqft                     0
# balconies                     0
# floor                         0
# location_rating               0
# age_years                     0
# furnishing                    0
# parking_spaces                0
# distance_to_city_center_km    0
# rent_price                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 🔹 Step 3: Data Processing
# - Check DataType

# %%
# Check DataType
df.dtypes
# Out:
# bedrooms                        int64
# bathrooms                     float64
# area_sqft                     float64
# balconies                       int64
# floor                           int64
# location_rating                 int64
# age_years                       int64
# furnishing                      int64
# parking_spaces                  int64
# distance_to_city_center_km    float64
# rent_price                    float64
# dtype: object

# %% [markdown]
# ### 🔹 Step 4: Data Analysis

# %%
df.describe()
# Out:
#            bedrooms     bathrooms     area_sqft     balconies        floor  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean       2.990300      2.001015   1710.085523      1.006000      9.91350
# std        1.423239      0.809978    745.425409      0.818432      5.44428
# min        1.000000      1.000000    400.000000      0.000000      1.00000
# 25%        2.000000      1.000000   1070.000000      0.000000      5.00000
# 50%        3.000000      2.000000   1708.377375      1.000000     10.00000
# 75%        4.000000      3.000000   2352.000000      2.000000     15.00000
# max        5.000000      3.000000   2998.000000      2.000000     19.00000
#
#        location_rating     age_years    furnishing  parking_spaces  \
# count     10000.000000  10000.000000  10000.000000     10000.00000
# mean          3.003800     14.570300      0.507200         0.99990
# std           1.425899      8.663381      0.499973         0.81189
# ...

# %%
df.groupby('location_rating')['rent_price'].mean()
# Out:
# location_rating
# 1    63.114208
# 2    66.887003
# 3    68.745364
# 4    72.257611
# 5    74.841182
# Name: rent_price, dtype: float64

# %% [markdown]
# ### 🔹 STEP 5: Data Visualization
# - 📊 Bar Chart — Bedrooms vs Average Rent

# %%
import matplotlib.pyplot as plt

bedroom_rent = df.groupby('bedrooms')['rent_price'].mean()

plt.bar(bedroom_rent.index, bedroom_rent.values)
plt.xlabel("Bedrooms")
plt.ylabel("Average Rent")
plt.title("Bedrooms vs Average Rent")
plt.show()

# %% [markdown]
# - 📈 Scatter Plot — Area vs Rent

# %%
plt.scatter(df['area_sqft'], df['rent_price'])
plt.xlabel("Area (sqft)")
plt.ylabel("Rent Price")
plt.title("Area vs Rent Price")
plt.show()

# %% [markdown]
# - Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# correlation matrix
corr = df.corr()

plt.figure(figsize=(10, 7))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of House Rent Dataset")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

X = df.drop('rent_price', axis=1)
y = df['rent_price']

model = RandomForestRegressor()
model.fit(X, y)

importance = pd.Series(model.feature_importances_, index=X.columns)
importance.sort_values().plot(kind='barh')
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ### ✅ STEP 6: Insights & Observations (Short)
# - Rent price increases as the house area increases.
# - Houses with more bedrooms have higher rent.
# - Properties with better location rating have higher rent.
# - Rent decreases as the distance from city center increases.
# - Furnished houses generally have higher rent than unfurnished houses.

# %% [markdown]
# ### ✅ STEP 7: Decision Making (Short)
# - People can choose houses based on their budget and requirements.
# - Houses near the city center should be selected only if the budget is high.
# - For lower rent, houses farther from the city center can be preferred.
# - Furnished houses can be chosen for better comfort if budget allows.
# - The model can help in predicting rent price for new houses.

# %% [markdown]
# ## **Pratical - 6**
# - Create one basic visualization using Excel / Google Sheets / Tableau / Power BI

# %% [markdown]
# ## **Section-B**
# ## **Pratical - 7**
# - Create an area chart for time-series data such as yearly profit or rainfall data.

# %%
df = pd.read_csv('/content/global_sports_footwear_sales_2018_2026.csv')
df.head(5)
# Out:
#     order_id  order_date   brand model_name    category  gender  size  color  \
# 0  ORD100000  2021-01-30   ASICS  Model-370     Running  Unisex     8  Black
# 1  ORD100001  2026-10-05  Reebok  Model-314   Lifestyle     Men     8   Grey
# 2  ORD100002  2023-11-12   ASICS  Model-763   Lifestyle     Men     8  Black
# 3  ORD100003  2026-08-29  Reebok  Model-905  Basketball   Women     7  White
# 4  ORD100004  2019-11-09    Nike  Model-413    Training     Men    11  Black
#
#    base_price_usd  discount_percent  final_price_usd  units_sold  revenue_usd  \
# 0             162                15           137.70           1        137.7
# 1              80                 5            76.00           3        228.0
# 2             176                15           149.60           4        598.4
# 3              61                15            51.85           2        103.7
# 4              80                 0            80.00           4        320.0
#
# ...

# %%
# Convert order_date to datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Extract year
df['Year'] = df['order_date'].dt.year

# Calculate yearly profit (total revenue)
yearly_profit = df.groupby('Year')['revenue_usd'].sum()

# Create area chart
plt.figure(figsize=(8,5))
plt.fill_between(yearly_profit.index, yearly_profit.values)

plt.xlabel("Year")
plt.ylabel("Total Revenue (USD)")
plt.title("Yearly Profit Area Chart")

plt.show()

# %% [markdown]
# ## **Pratical - 8**
# - Draw a scatter plot to show relationship between two variables (study hours vs marks).

# %%
df = pd.read_csv('/content/marksheet_practical.csv')
df.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths  \
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21
#
#    Total_marks  Study_hour
# 0          213           2
# 1          127           2
# 2          211           3
# 3          183           2
# 4           73           1

# %%
plt.scatter(df['Study_hour'], df['Total_marks'])
plt.xlabel("Study Hours")
plt.ylabel("Total Marks")
plt.title("Study Hours vs Total Marks")

plt.show()

# %% [markdown]
# ## **Pratical - 9**
# - Create a pivot table and pivot chart using a simple dataset.

# %%
df = pd.read_csv('/content/marksheet_practical.csv')
df.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths  \
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21
#
#    Total_marks  Study_hour
# 0          213           2
# 1          127           2
# 2          211           3
# 3          183           2
# 4           73           1

# %% [markdown]
# ### Create Pivot Table

# %%
pivot_table = pd.pivot_table(
    df,
    values=['Science', 'English', 'History', 'Maths', 'Total_marks'],
    index=['Section'],  # Added 'Section' as the index
    aggfunc='mean'
)

# Display pivot table
pivot_table
# Out:
#            English  History      Maths    Science  Total_marks
# Section
# A        45.333333    36.00  53.333333  45.666667   180.333333
# B        55.750000    49.75  49.500000  39.250000   194.250000
# C        81.666667    48.00  72.333333  27.000000   229.000000

# %% [markdown]
# ### Create Pivot Chart (Bar Chart)

# %%
pivot_table.plot(kind='bar')

plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.title("Overall Pivot Chart - Average Marks")

plt.show()

# %% [markdown]
# ## **Pratical - 10**
# - Design a tree map to represent category-wise data.

# %%
pip install squarify

# %%
# Section-wise total marks
import squarify

section_data = df.groupby('Section')['Total_marks'].sum().reset_index()

# Create Treemap
plt.figure(figsize=(8,5))
squarify.plot(
    sizes=section_data['Total_marks'],
    label=section_data['Section'],
    alpha=0.8
)

plt.title("Tree Map: Section-wise Total Marks")
plt.axis('off')

plt.show()

# %% [markdown]
# ## **Pratical - 11**
# - Draw a simple node-link diagram to show relationships.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create graph
G = nx.Graph()

# Add nodes
G.add_nodes_from(["Course", "BCA","MCA", "BBA", "B.Tech", "MBA"])

# Add relationships
G.add_edge("Course", "BCA")
G.add_edge("Course", "MCA")
G.add_edge("Course", "BBA")
G.add_edge("Course", "B.Tech")
G.add_edge("Course", "MBA")

# Draw node-link diagram
plt.figure(figsize=(7,5))
nx.draw(G, with_labels=True, node_size=3000)

plt.title("Node-Link Diagram: Department and Courses")
plt.show()

# %% [markdown]
# ## **Pratical - 12**
# - Visualize correlation between numerical variables using heatmap.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('/content/marksheet_practical.csv')

# Select numerical columns
num_data = df[['Age', 'Science', 'English', 'History', 'Maths', 'Total_marks', 'Study_hour']]

# Create correlation matrix
corr = num_data.corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap of Numerical Variables")
plt.show()

# %% [markdown]
# ## **Section-C**
# ## **Pratical - 13**
# - Create a time-series visualization with multiple variables and
# analyze patterns.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Sales Dataset.csv')

plt.plot(df["Year"], df["Sales"], marker='o', label="Sales")
plt.plot(df["Year"], df["Profit"], marker='o', label="Profit")

plt.title("Sales and Profit Trend")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()

plt.show()

# %% [markdown]
# ## **Pratical - 14**
# - Perform text visualization by word frequency and plot it.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV file read
df = pd.read_csv("words_dataset.csv")

# word frequency count
word_count = df["word"].value_counts()

# bar chart
word_count.plot(kind="bar")

plt.title("Word Frequency Visualization")
plt.xlabel("Words")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## **Pratical - 15**
# - Create a multivariate chart using more than two variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read dataset
df = pd.read_csv("student_performance.csv")

plt.figure(figsize=(9,6))

scatter = plt.scatter(
    df["Study_Hours"],
    df["Marks"],
    s=df["Attendance"]*8,       # bubble size based on attendance
    c=df["Sleep_Hours"],        # color based on sleep hours
    cmap="viridis",
    edgecolors="black",
    alpha=0.8
)

plt.title("Multivariate Visualization: Study Hours vs Marks", fontsize=14)
plt.xlabel("Study Hours", fontsize=12)
plt.ylabel("Marks", fontsize=12)

plt.grid(True)

# color bar
cbar = plt.colorbar(scatter)
cbar.set_label("Sleep Hours")

plt.show()

# %% [markdown]
# ## **Pratical - 16**
# - Study a small case example where visualization helps in
# understanding data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# dataset read
df = pd.read_csv("monthly_sales.csv")

# line chart
plt.plot(df["Month"], df["Online_Sales"], marker="o", label="Online Sales")
plt.plot(df["Month"], df["Store_Sales"], marker="o", label="Store Sales")

plt.title("Monthly Sales Analysis")
plt.xlabel("Month")
plt.ylabel("Sales Amount")

plt.legend()
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("sales_data2.csv")

# %%
df.sample(10)
# Out:
#     Order_ID       City     Category  Price  Discount  Final_Price
# 12       113      Delhi    Groceries   1000         6          940
# 6        107  Bangalore    Groceries   1200         8         1104
# 16       117      Delhi     Clothing   2800        20         2240
# 11       112    Kolkata  Electronics  25000        12        22000
# 19       120    Kolkata     Clothing   3200        25         2400
# 5        106     Mumbai  Electronics  18000        10        16200
# 3        104    Kolkata    Groceries    800         5          760
# 10       111  Bangalore     Clothing   2700        18         2214
# 0        101      Delhi  Electronics  15000        10        13500
# 14       115  Bangalore  Electronics  21000        15        17850

# %%
# 1. Category-wise Total Sales
category_sales = df.groupby("Category")["Final_Price"].sum()

plt.figure()
category_sales.plot(kind='bar')
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
# 2. City-wise Sales
city_sales = df.groupby("City")["Final_Price"].sum()

plt.figure()
city_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales Distribution by City")
plt.ylabel("")
plt.show()

# %%
# 3. Discount vs Final Price (Scatter Plot)
plt.figure()
plt.scatter(df["Discount"], df["Final_Price"])
plt.title("Discount vs Final Price")
plt.xlabel("Discount (%)")
plt.ylabel("Final Price")
plt.show()

# %%
# 4. Category-wise Average Discount
avg_discount = df.groupby("Category")["Discount"].mean()

plt.figure()
avg_discount.plot(kind='bar')
plt.title("Average Discount per Category")
plt.xlabel("Category")
plt.ylabel("Discount (%)")
plt.show()

# %% [markdown]
# ## **Pratical - 17**
# - Create a live-like data visualization using continuously updated
# values.

# %%
import matplotlib.pyplot as plt
import random

x = []
y = []

for i in range(10):
    x.append(i)
    y.append(random.randint(10,100))

plt.plot(x,y, marker='o')

plt.title("Live Data Simulation")
plt.xlabel("Time")
plt.ylabel("Values")

plt.show()

# %% [markdown]
# ## **Pratical - 18**
# - Write basic rules or best practices for good visualization with
# examples.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("sales.csv")

# GOOD Visualization
plt.figure()
plt.plot(df["Month"], df["Sales"], marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid()
plt.show()

# BAD Visualization (example purpose)
plt.figure()
plt.plot(df["Month"], df["Sales"])
plt.title("Graph")
plt.show()

# %% [markdown]
# ## **Pratical - 19**
# - Create a basic chart to show open and closed ports from given
# data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ports_data.csv")

# direct bar chart
plt.bar(df["Port"].astype(str), df["Status"])

plt.title("Open and Closed Ports")
plt.xlabel("Port")
plt.ylabel("Status")

plt.show()

# %% [markdown]
# ## **Pratical - 20**
# - Create a firewall log visualization to identify suspicious traffic.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read dataset
df = pd.read_csv("firewall_data.csv")

# colors for better visualization
colors = ["green", "red", "yellow"]

plt.figure(figsize=(7,5))

plt.bar(df["Traffic_Type"], df["Count"], color=colors)

plt.title("Firewall Traffic Analysis")
plt.xlabel("Traffic Type")
plt.ylabel("Number of Requests")

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# ## **Pratical - 21**
# - Design an intrusion detection log visualization and highlight
# possible attacks.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read dataset
df = pd.read_csv("intrusion_logs.csv")

plt.figure(figsize=(9,5))

# multiple lines (multivariate)
plt.plot(df["Time"], df["Normal"], marker='o', label="Normal")
plt.plot(df["Time"], df["SQL_Injection"], marker='o', label="SQL Injection")
plt.plot(df["Time"], df["DDoS"], marker='o', label="DDoS")
plt.plot(df["Time"], df["Malware"], marker='o', label="Malware")
plt.plot(df["Time"], df["Phishing"], marker='o', label="Phishing")

plt.title("Intrusion Detection Over Time")
plt.xlabel("Time")
plt.ylabel("Number of Attempts")

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ## **Pratical - 22**
# - Write a program to implement sentiment analysis on live tweet
# data using Python.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read dataset
df = pd.read_csv("tweets.csv")

# simple sentiment function
def sentiment(text):
    text = text.lower()

    if "love" in text or "amazing" in text or "happy" in text or "excellent" in text or "nice" in text:
        return "Positive"
    elif "bad" in text or "worst" in text or "boring" in text or "disappointing" in text:
        return "Negative"
    else:
        return "Neutral"

# apply sentiment
df["Sentiment"] = df["Tweet"].apply(sentiment)

# count sentiments
result = df["Sentiment"].value_counts()

# plot graph
plt.bar(result.index, result.values, color=["green","blue","red"])

plt.title("Tweet Sentiment Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## **Pratical - 23**
# - Create interactive visualizations to monitor IoT device activity in
# real-time.

# %%
import matplotlib.pyplot as plt
import random
import time

time_data = []
temp_data = []

plt.figure()

for i in range(10):   # 10 updates (live simulation)
    time_data.append(i)
    temp_data.append(random.randint(24,35))  # random temperature

    plt.clf()   # clear previous graph

    plt.plot(time_data, temp_data, marker='o')

    plt.title("IoT Device Temperature Monitoring")
    plt.xlabel("Time")
    plt.ylabel("Temperature (°C)")

    plt.grid(True)

    plt.pause(0.5)   # delay (live effect)

plt.show()

# %% [markdown]
# ## **Pratical - 24**
# - Design a secured data visualization system architecture and
# explain security measures.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# boxes positions
boxes = {
    "Data Source": (1,5),
    "Authentication": (3,5),
    "Processing": (5,5),
    "Database": (7,5),
    "Visualization": (9,5),
    "User": (11,5)
}

# draw boxes
for text, (x,y) in boxes.items():
    plt.text(x, y, text, ha='center', va='center',
             bbox=dict(boxstyle="round", facecolor="lightblue"))

# arrows
plt.arrow(1.5,5,1,0, head_width=0.2, length_includes_head=True)
plt.arrow(3.5,5,1,0, head_width=0.2)
plt.arrow(5.5,5,1,0, head_width=0.2)
plt.arrow(7.5,5,1,0, head_width=0.2)
plt.arrow(9.5,5,1,0, head_width=0.2)

plt.title("Secure Data Visualization Architecture")

plt.xlim(0,12)
plt.ylim(4,6)

plt.axis('off')

plt.show()
